# %% [markdown]
# ## QF-104: Data Management in R

# %% [markdown]
# #### Instructors:
# #### Section A - Mohamad Afkhami
# #### Section B, C - Olorundamilola 'Dami' Kazeem
# ### Semester: 2019 Spring

# %% [markdown]
# #### What is R?

# %% [markdown]
# - R is an overgrown calculator.

# %% [markdown]
# * R is a free software for statistical computing and visualization.

# %% [markdown]
# * R is a programming language.

# %% [markdown]
# #### What is RStudio?

# %% [markdown]
# * RStudio is a free IDE (intergarted development environment) specifically for R.

# %% [markdown]
# ![week01_r4ds_1-4.png](attachment:week01_r4ds_1-4.png)

# %% [markdown]
# ![week01_rsutdio_ide.png](attachment:week01_rsutdio_ide.png)

# %% [markdown]
# ![week01_rstudio_ide_00.png](attachment:week01_rstudio_ide_00.png)

# %%
6+7

# %%
10*4/2+3

# %%
exp(2)

# %%
x<-9

# %%
x

# %%
x<-6+7

# %%
x

# %%
y<-x+x

# %%
y

# %%
rnorm(5)

# %%
plot(rnorm(5))

# %%
install.packages("ISwR")

# %%
library(ISwR)

# %%
plot(rnorm(1000))

# %%
# install.packages("tidyverse")
library(tidyverse)

# %% [markdown]
# - https://tidyverse.tidyverse.org/
# - https://tidyverse.tidyverse.org/reference/tidyverse_conflicts.html

# %%
tidyverse_conflicts()

# %%
help(mpg)

# %%
head(mpg)

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy))

# %%
# library(datasets)
